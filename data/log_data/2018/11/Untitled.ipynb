# %%
import json
import pandas as pd

# %%
f = open('2018-11-01-events.json', 'r')

# %%
df = pd.read_json('2018-11-10-events.json', lines=True)

# %%
df
# Out:
#                                                artist       auth firstName  \
# 0                                          Hoobastank  Logged In    Cierra
# 1                                       Mark Knopfler  Logged In    Cierra
# 2                                              Mogwai  Logged In    Cierra
# 3                                      The Casualties  Logged In    Cierra
# 4                                                None  Logged In   Cecilia
# 5                                      The Living End  Logged In      Ryan
# 6                                          Aloe Blacc  Logged In     Rylan
# 7                                       Faith No More  Logged In     Rylan
# 8                                       Chris Cornell  Logged In    Aleena
# 9                                              Weezer  Logged In    Aleena
# 10                     Stream of Passion feat. Ayreon  Logged In    Aleena
# ...

# %%
df['location'].describe()
# Out:
# count                              15
# unique                              5
# top       Phoenix-Mesa-Scottsdale, AZ
# freq                                9
# Name: location, dtype: object

# %%
df2 = pd.read_json('./TRAAARJ128F9320760.json', lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-75ad06d0e503> in <module>()
# ----> 1 df2 = pd.read_json('./TRAAARJ128F9320760.json', lines=True)
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/json/json.py in read(self)
#     524             data = to_str(self.data)
#     525             obj = self._get_object_parser(
# --> 526                 self._combine_lines(data.split('\n'))
#     527             )
#     528         else:
#
# ...
